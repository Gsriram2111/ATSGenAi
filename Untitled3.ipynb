# %% [markdown]
# <a href="https://colab.research.google.com/github/Gsriram2111/ATSGenAi/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.12/dist-packages (3.0.1)

# %%
pip install google
# Out:
# Requirement already satisfied: google in /usr/local/lib/python3.12/dist-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from google) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->google) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->google) (4.15.0)

# %%
pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (1.55.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.12.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.14.1->google-genai) (2.43.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
from google import genai
from google.genai import types

# %%
import PyPDF2
def extract_text_from_pdf(pdf_path):
    extracted_text = ""
    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text

# %%
pdf=(extract_text_from_pdf("/content/sriramnew.pdf"))

# %%
client = genai.Client(api_key='AIzaSyBgUJaAusTx4')

# %%
a=input("enter job description")
# Out:
# enter job descriptionfull stack developer

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents={f'context: here is my resume {pdf} and job description {a}',
     'text:based on the job description give me ats score.' },
)

# %%
print(response.text)
# Out:
# Given your resume and the generic "Full Stack Developer" job description, here's an ATS score and analysis:
#
# ---
#
# ## ATS Score: 92%
#
# ### Analysis & Strengths:
#
# Your resume is exceptionally well-aligned for a Full Stack Developer role, covering a broad range of essential technologies and demonstrating practical application through projects.
#
# 1.  **Programming Languages (Excellent Match):**
#     *   **Keywords:** C, C++, Java, Python, JavaScript (ES6+).
#     *   **Resume Match:** All explicitly listed under "Programming Languages" and demonstrated in projects. Python (Django) and JavaScript (React.js, Node.js) are key full-stack languages you possess.
#
# 2.  **Frontend Development (Excellent Match):**
#     *   **Keywords:** HTML5, CSS3, JavaScript, React.js, Responsive Design, UI/UX (implied).
#     *   **Resume Match:** All explicitly listed. React.js and Tailwind CSS are modern, in-demand frontend technologies, and your projects (CrizScore, Movie Search) clearly showcase their application and responsive UI design.
#
# 3.  **Backend & APIs (Strong Match):**
#     *   **Keywords:** Node.js, Python (Django/Flask), RESTful APIs, Backend development.
#     *   **Resume Match:** Node.js and RESTful APIs are explicitly listed. Django (Python framework) is prominently featured in your "Social Media Web Application" project, demonstrating strong backend capabilities, including user authentication and CRUD operations.
#
# 4.  **Databases (Strong Match):**
#     *   **Keywords:** MySQL, MongoDB, SQL, NoSQL.
#     *   **Resume Match:** MySQL and MongoDB are explicitly listed. SQLite is also mentioned in a project, showing versatility.
#
# 5.  **Core CS (Excellent Match):**
#     *   **Keywords:** Data Structures & Algorithms, OOP, DBMS, OS, Computer Networks.
#     *   **Resume Match:** All explicitly listed. These are fundamental for any strong developer role.
#
# 6.  **Tools & Version Control (Excellent Match):**
#     *   **Keywords:** Git, GitHub, VS Code.
#     *   **Resume Match:** All explicitly listed. Figma is also a good addition for UI/UX aspects.
#
# 7.  **Projects (Outstanding Validation):**
#     *   Your three projects are **highly relevant** and demonstrate full-stack capabilities, API integration, UI development, and database interactions. They are your strongest asset in an ATS context.
#     *   "Social Media Web Application" directly covers backend (Django, SQLite, auth, CRUD).
#     *   "CrizScore" and "Movie Search" strongly showcase frontend (React, Tailwind) with API integration, which is a core full-stack skill.
#
# 8.  **Certifications (Strong Plus):**
#     *   **Keywords:** Cloud, AWS.
#     *   **Resume Match:** "AWS Cloud Practitioner Essentials" is an excellent addition, showing foundational cloud knowledge, which is increasingly important for full-stack developers.
#
# ### Areas for Improvement (To reach 100% and beyond):
#
# 1.  **Testing Frameworks:** While not always required for entry-level, mentioning experience with testing frameworks (e.g., Jest, React Testing Library for frontend; Pytest for Python; Mocha/Chai for Node.js) would significantly boost your score for more advanced roles.
# 2.  **Deployment/DevOps:** You have AWS, which is a great start. Explicitly mentioning experience with deploying applications (e.g., to AWS EC2, Netlify, Vercel, Heroku) or basic CI/CD (Continuous Integration/Continuous Deployment) concepts would be beneficial.
# 3.  **Containerization:** Familiarity with Docker is a common requirement for full-stack roles now.
# 4.  **Specific Backend Frameworks:** While you listed Node.js, specifying if you've worked with popular Node.js frameworks like Express.js would add more weight.
# 5.  **Quantifiable Impact:** Where possible, try to quantify achievements in your projects (e.g., "Improved load time by X%," "Handled Y concurrent users," "Reduced database query time by Z"). This is harder for personal projects but impactful.
# 6.  **Keywords in Experience:** Your AI & Machine Learning internship, while showcasing technical skills, is not directly "full stack." If the job description specifically mentions AI/ML, it's a perfect match. Otherwise, ensure you highlight *transferable skills* from this experience that are relevant to software development (e.g., problem-solving, algorithm implementation, prototype development).
#
# ---
#
# **Overall:** Your resume is very strong for a Full Stack Developer. The ATS will pick up almost all relevant keywords due to your clear skill categorization and project demonstrations. Good luck!
