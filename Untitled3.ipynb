# %% [markdown]
# <a href="https://colab.research.google.com/github/Gsriram2111/ATSGenAi/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2

# %%
pip install google

# %%
pip install google-genai

# %%
from google import genai
from google.genai import types

# %%
import PyPDF2
def extract_text_from_pdf(pdf_path):
    extracted_text = ""
    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text

# %%
pdf=(extract_text_from_pdf("/content/sriramnew.pdf"))

# %%
client = genai.Client(api_key='AIzaSyBgUJaAusTx4KUCqa1xwiYsMw44t2jjE14')

# %%
a=input("enter job description")
# Out:
# enter job descriptionfull stack developet

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents={f'context: here is my resume {pdf} and job description {a}',
     'text:based on the job description give me ats score.' },
)

# %%
print(response.text)
# Out:
# Okay, let's break down your resume against the implicit "full stack developer" job description.
#
# **ATS Score: 90%**
#
# This is an excellent score for an entry-level/junior full-stack role. Your resume is very well-structured, uses clear terminology, and hits almost all the key technical keywords expected for a full-stack developer.
#
# **Explanation of Score:**
#
# Your resume demonstrates a strong command of both front-end and back-end technologies, which is exactly what an ATS is looking for when screening for a "full stack developer." You have a great mix of programming languages, frameworks, databases, and core computer science concepts.
#
# **Keyword Matches (Examples):**
#
# *   **Full Stack Developer:** While not explicitly on your resume as a past role (which is fine for a student), your *entire skill set* and *project list* scream "full stack."
# *   **Frontend:** HTML5, CSS3, JavaScript (ES6+), React.js, Tailwind CSS, Responsive UI (from project).
# ...
